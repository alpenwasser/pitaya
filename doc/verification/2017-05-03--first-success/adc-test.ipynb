# %%
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt

# %matplotlib inline

df         = pd.read_csv('adc-read-sine--2017-05-03.txt')
df_clipped = pd.read_csv('adc-read-sine--clipped--2017-05-03.txt')


df.VALUE=list(map(lambda x: int(x,16),df.VALUE))
df_clipped.VALUE=list(map(lambda x: int(x,16),df_clipped.VALUE))

plt.figure()
plt.rcParams['figure.figsize']=16,10
df.plot()

plt.figure()
plt.rcParams['figure.figsize']=16,10
df_clipped.plot()

# %%
f = open('upper_clipped_sine.txt')
plt.figure()
plt.rcParams['figure.figsize']=16,10
plt.plot([int(l, 16) for l in f.readline().split(' ')])
f.close()
f = open('middle_sine_wrap.txt')
plt.figure()
plt.rcParams['figure.figsize']=16,10
plt.plot([int(l, 16) for l in f.readline().split(' ')])
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c1b50f6afee> in <module>()
#       1 f = open('upper_clipped_sine.txt')
# ----> 2 plt.figure()
#       3 plt.rcParams['figure.figsize']=16,10
#       4 plt.plot([int(l, 16) for l in f.readline().split(' ')])
#       5 f.close()
#
# NameError: name 'plt' is not defined

# %%
f = open('middle_sine_2.txt')
plt.figure()
plt.rcParams['figure.figsize']=16,10
plt.plot([int(l, 16) for l in f.readline().split(' ')])
f.close()

# %%
f = open('correct_data_format_idle.txt')
plt.figure()
plt.rcParams['figure.figsize']=16,10
plt.plot([int(l, 16) for l in f.readline().split(' ')])
f.close()

# %%
f = open('broken_fir.txt')
plt.figure()
plt.rcParams['figure.figsize']=16,10
plt.plot([int(l, 16) for l in f.readline().split(' ')])
f.close()

# %%
import scipy.stats

f = open('scaling.txt')
plt.figure()
plt.rcParams['figure.figsize']=16,10
x = [int(l, 16) / 2**16 * 2.2 - 1.1 for l in f.readline().split(' ')]
#0.2789 in scope
plt.plot(x)
f.close()

# %%
import scipy.stats

f = open('scaling_no_filt.txt')
plt.figure()
plt.rcParams['figure.figsize']=16,10
x = [int(l, 16) / 2**14 * 2.2 - 1.1 for l in f.readline().split(' ')]
#0.2789 in scope
plt.plot(x)
f.close()
