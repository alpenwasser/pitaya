# %%
# Preparations
import math
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
from scipy import stats
from scipy.optimize import curve_fit
from IPython.display import Latex
import warnings
warnings.filterwarnings("ignore", module="matplotlib")
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.rcParams['savefig.dpi'] = 75

plt.style.use('ggplot')

print(plt.style.available)

# 1 second of data samples at spacing of 1/1000 seconds
t = np.arange(0, 1, 1.0/1000)
# sine wave of 100 Hz
s = np.sin(2 * math.pi * 100 * t)
# plot first 20 points of the resulting data (why not all 1000?)
plt.plot(s[:20])
plt.show()
# Out:
# ['ggplot', 'seaborn-whitegrid', 'seaborn-notebook', 'seaborn-dark-palette', 'fivethirtyeight', 'classic', 'seaborn-deep', 'seaborn-darkgrid', 'seaborn-bright', 'seaborn-ticks', 'grayscale', 'dark_background', 'seaborn-dark', 'seaborn-colorblind', 'seaborn-white', 'seaborn-pastel', 'seaborn-poster', 'seaborn-paper', 'bmh', 'seaborn-muted', 'seaborn-talk']
